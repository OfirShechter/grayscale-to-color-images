# %%
import zipfile
import os
import glob

# Path to the data directory
data_dir = "data"
output_dir = os.path.join(data_dir, "color-images")

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Find all zip files in the data directory
zip_files = glob.glob(os.path.join(data_dir, "*.zip"))

print(f"Found {len(zip_files)} zip files to extract:")
for zip_file in zip_files:
    print(f"  - {os.path.basename(zip_file)}")

# Extract each zip file
for zip_file in zip_files:
    print(f"\nExtracting {os.path.basename(zip_file)}...")
    try:
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(output_dir)
        print(f"  ✓ Successfully extracted {os.path.basename(zip_file)}")
    except Exception as e:
        print(f"  ✗ Error extracting {os.path.basename(zip_file)}: {str(e)}")

print(f"\nExtraction complete! All files extracted to: {output_dir}")

# List the contents of the output directory
print(f"\nContents of {output_dir}:")
try:
    files = os.listdir(output_dir)
    files.sort()
    for i, file in enumerate(files, 1):
        file_path = os.path.join(output_dir, file)
        if os.path.isfile(file_path):
            size = os.path.getsize(file_path)
            print(f"  {i:3d}. {file} ({size:,} bytes)")
        else:
            print(f"  {i:3d}. {file}/ (directory)")
    print(f"\nTotal items: {len(files)}")
except Exception as e:
    print(f"Error listing directory contents: {str(e)}")
# Out:
# Found 15 zip files to extract:
#   - Data-20250803T102502Z-1-012.zip
#   - Data-20250803T102502Z-1-009.zip
#   - Data-20250803T102502Z-1-015.zip
#   - Data-20250803T102502Z-1-011.zip
#   - Data-20250803T102502Z-1-005.zip
#   - Data-20250803T102502Z-1-006.zip
#   - Data-20250803T102502Z-1-007.zip
#   - Data-20250803T102502Z-1-003.zip
#   - Data-20250803T102502Z-1-008.zip
#   - Data-20250803T102502Z-1-014.zip
#   - Data-20250803T102502Z-1-002.zip
#   - Data-20250803T102502Z-1-010.zip
#   - Data-20250803T102502Z-1-004.zip
#   - Data-20250803T102502Z-1-001.zip
#   - Data-20250803T102502Z-1-013.zip
#
# Extracting Data-20250803T102502Z-1-012.zip...
#   ✓ Successfully extracted Data-20250803T102502Z-1-012.zip
#
# Extracting Data-20250803T102502Z-1-009.zip...
#   ✓ Successfully extracted Data-20250803T102502Z-1-009.zip
#
# Extracting Data-20250803T102502Z-1-015.zip...
#   ✓ Successfully extracted Data-20250803T102502Z-1-015.zip
#
# Extracting Data-20250803T102502Z-1-011.zip...
# ...
